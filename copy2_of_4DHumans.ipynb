# %% [markdown]
# <a href="https://colab.research.google.com/github/ravidufig/PHALPTest/blob/master/copy2_of_4DHumans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4DHumans Demo Notebook
# This a demo notebook for our paper "4DHumans: Reconstructing and Tracking Humans with Transformers".
#
# <p align="left"><img src="https://github.com/shubham-goel/4D-Humans/raw/main/assets/teaser.png" width="800"></p>
#
# <p align="left"><img src="https://github.com/brjathu/PHALP/raw/master/assets/imgs/teaser.gif" width="800"></p>
#
# Project webpage: https://shubham-goel.github.io/4dhumans/
#
# Github repo: https://github.com/shubham-goel/4D-Humans
#
# Instructions:
#
# 1. Enable the GPU Runtime (Runtime > Change Runtime Type > GPU)
# 2. Clone the repository and install depencencies
# 3. Run the demo
# 4. Visualize the video

# %% [markdown]
# # Clone the repository and install dependencies

# %%
# Clone the main repo
# %%capture
! git clone https://github.com/shubham-goel/4D-Humans.git 4D-Humans
# %cd 4D-Humans

# %%
# !pip install torch
# !pip install -e .[all]
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Obtaining file:///content/4D-Humans
#   Preparing metadata (setup.py) ... done
# Collecting chumpy@ git+https://github.com/mattloper/chumpy (from hmr2==0.0.0)
#   Cloning https://github.com/mattloper/chumpy to /tmp/pip-install-r1j6auiq/chumpy_5faacb98e6274bf6a091ae834028e7ed
#   Running command git clone --filter=blob:none --quiet https://github.com/mattloper/chumpy /tmp/pip-install-r1j6auiq/chumpy_5faacb98e6274bf6a091ae834028e7ed
#   Resolved https://github.com/mattloper/chumpy to commit 51d5afd92a8ded3637553be8cef41f328a1c863a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (5.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (2.4.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.19.0+cu121)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (2.4.0)
# Requirement already satisfied: smplx==0.1.28 in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.1.28)
# Requirement already satisfied: pyrender in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.1.45)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (4.10.0.84)
# Requirement already satisfied: yacs in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.1.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.23.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.8.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (1.0.9)
# Requirement already satisfied: webdataset in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.2.100)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (2.1.4)
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2 (from hmr2==0.0.0)
#   Cloning https://github.com/facebookresearch/detectron2 to /tmp/pip-install-r1j6auiq/detectron2_eacd228cf0bf4023983570f5d314e9d6
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2 /tmp/pip-install-r1j6auiq/detectron2_eacd228cf0bf4023983570f5d314e9d6
#   Resolved https://github.com/facebookresearch/detectron2 to commit ebe8b45437f86395352ab13402ba45b75b4d1ddb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (2024.6.1)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->hmr2==0.0.0) (1.13.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->hmr2==0.0.0) (1.16.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.0.8)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.66.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.17.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (24.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (24.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from yacs->hmr2==0.0.0) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->hmr2==0.0.0) (4.12.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown->hmr2==0.0.0) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->hmr2==0.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hmr2==0.0.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hmr2==0.0.0) (2024.1)
# Requirement already satisfied: freetype-py in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (2.5.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (2.34.2)
# Requirement already satisfied: pyglet>=1.4.10 in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (2.0.17)
# Requirement already satisfied: PyOpenGL==3.1.0 in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (3.1.0)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (4.4.9)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->hmr2==0.0.0) (1.4.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->hmr2==0.0.0) (0.11.7)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->hmr2==0.0.0) (2024.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->hmr2==0.0.0) (0.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm->hmr2==0.0.0) (0.24.6)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->hmr2==0.0.0) (0.4.4)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.10/dist-packages (from webdataset->hmr2==0.0.0) (0.1.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (3.10.5)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->hmr2==0.0.0) (71.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->hmr2==0.0.0) (2.6)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.2.2)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->hmr2==0.0.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->hmr2==0.0.0) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (4.0.3)
# Installing collected packages: hmr2
#   Attempting uninstall: hmr2
#     Found existing installation: hmr2 0.0.0
#     Uninstalling hmr2-0.0.0:
#       Successfully uninstalled hmr2-0.0.0
#   Running setup.py develop for hmr2
# Successfully installed hmr2-0.0.0

# %%
# %cd /content/4D-Humans
# !wget https://github.com/classner/up/raw/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# !mkdir data/
# !cp basicModel_neutral_lbs_10_207_0_v1.0.0.pkl ./data/
# Out:
# /content/4D-Humans
# --2024-09-10 13:45:07--  https://github.com/classner/up/raw/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2024-09-10 13:45:07--  https://raw.githubusercontent.com/classner/up/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl.1’
#
# basicModel_neutral_ 100%[===================>]  37.19M  --.-KB/s    in 0.1s
#
# 2024-09-10 13:45:08 (363 MB/s) - ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl.1’ saved [39001280/39001280]
#
# mkdir: cannot create directory ‘data/’: File exists

# %% [markdown]
# # Run the demo

# %%
# run hmr2 on a folder of images
# !python demo.py \
--img_folder example_data/images \
--out_folder demo_out \
--batch_size=48 --side_view --save_mesh
# Out:
# Downloading file: hmr2_data.tar.gz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/4dhumans/hmr2_data.tar.gz to /root/.cache/4DHumans/hmr2_data.tar.gz
#   [============================================================] 100.0% of 2585.0MB file
# Extracting file: hmr2_data.tar.gz
# data/
# data/smpl/
# data/smpl_mean_params.npz
# data/SMPL_to_J19.pkl
# logs/
# logs/train/
# logs/train/multiruns/
# logs/train/multiruns/hmr2/
# logs/train/multiruns/hmr2/0/
# logs/train/multiruns/hmr2/0/checkpoints/
# logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt
# logs/train/multiruns/hmr2/0/model_config.yaml
# logs/train/multiruns/hmr2/0/dataset_config.yaml
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/4DHumans/logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt`
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# model_final_f05665.pkl: 2.77GB [00:18, 146MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# downsampling_factor=11.122095108032227
# /content/4D-Humans/hmr2/utils/geometry.py:61: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at ../aten/src/ATen/native/Cross.cpp:62.)
#   b3 = torch.cross(b1, b2)
# (6890, 3) (3,)
# 239.53619813919067
# downsampling_factor=2.209404786427816
# downsampling_factor=1.1847938299179077
# downsampling_factor=1.2592133283615112
# downsampling_factor=1.2431062459945679
# downsampling_factor=1.1442233324050903
# downsampling_factor=1.2556993961334229
# downsampling_factor=1.2377299070358276
# downsampling_factor=1.2090665102005005
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# downsampling_factor=1.1495060920715332
# downsampling_factor=1.3079936504364014
# downsampling_factor=1.128129005432129
# downsampling_factor=1.2200064659118652
# downsampling_factor=0.9510793685913086
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# (6890, 3) (3,)
# 254.58644819259644

# %% [markdown]
# ### Visualize the reconstructions

# %%
from IPython.display import Image, display
import os
# https://colab.research.google.com/drive/1Ex4gE5v1bPR3evfhtG7sDHxQGsWwNwby?usp=sharing
output_images = ["demo_out/" + i for i in os.listdir("demo_out/") if ".png" in i]
for img in output_images:
  display(Image(img))

# %% [markdown]
# # Video Demo

# %% [markdown]
# ### Install PHALP

# %%
# !pip install git+https://github.com/ravidufig/PHALPTest.git
# Out:
# Collecting git+https://github.com/ravidufig/PHALPTest.git
#   Cloning https://github.com/ravidufig/PHALPTest.git to /tmp/pip-req-build-072wgtj3
#   Running command git clone --filter=blob:none --quiet https://github.com/ravidufig/PHALPTest.git /tmp/pip-req-build-072wgtj3
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/ravidufig/PHALPTest.git /tmp/pip-req-build-072wgtj3 did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/ravidufig/PHALPTest.git /tmp/pip-req-build-072wgtj3 did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %% [markdown]
# ### Track and visualize

# %%
# !pip install PyOpenGL-accelerate
# Out:
# Collecting PyOpenGL-accelerate
#   Downloading PyOpenGL_accelerate-3.1.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (789 bytes)
# Downloading PyOpenGL_accelerate-3.1.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: PyOpenGL-accelerate
# Successfully installed PyOpenGL-accelerate-3.1.7

# %%
# !python track.py video.source="example_data/videos/gymnasts.mp4" video.start_frame=10 video.end_frame=60
# Out:
# python3: can't open file '/content/track.py': [Errno 2] No such file or directory

# %%
import os
phalp_dir = os.path.dirname(PHALP.__file__)
print(f"PHALP is installed at: {phalp_dir}")

# Try to find track.py
# !find {phalp_dir} -name track.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b9f7a07d7d0> in <cell line: 2>()
#       1 import os
# ----> 2 phalp_dir = os.path.dirname(PHALP.__file__)
#       3 print(f"PHALP is installed at: {phalp_dir}")
#       4
#       5 # Try to find track.py
#
# NameError: name 'PHALP' is not defined

# %%
from google.colab import drive
drive.mount('/content/gdrive')
#!python track.py video.source="example_data/videos/gymnasts.mp4" video.start_frame=10 video.end_frame=60
# !python track.py video.source="/content/gdrive/My Drive/Colab Notebooks/crowd02.mp4" video.start_frame=10 video.end_frame=60
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# python3: can't open file '/content/track.py': [Errno 2] No such file or directory

# %%
# Display the reconstruction video
def show_local_mp4_video(file_name, width=640, height=480):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                      <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

# !ffmpeg -y -hide_banner -loglevel error -i outputs/PHALP_gymnasts.mp4 outputs/PHALP_gymnasts_ffmpeg.mp4
show_local_mp4_video('outputs/PHALP_gymnasts_ffmpeg.mp4', width=960, height=540)
# Out:
# <video width="960" height="540" alt="test" controls>
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                       </video>
